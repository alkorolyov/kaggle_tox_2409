# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

# %%
import time

import numpy as np
import pandas as pd

from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, KFold
from src.utils import OffsetScaler, get_fps_offset
import xgboost as xgb
import catboost as cb
import lightgbm as lgb
import seaborn as sns


mae = 'neg_mean_absolute_error'
mse = 'neg_mean_squared_error'
rmse = 'neg_root_mean_squared_error'
roc_auc = 'neg_roc_auc_score'
N_JOBS = 24
RANDOM_SEED = 42

# %%
def get_objectives(X, y):
    objectives = {}

    # Logistic Regression
    def logistic_regression_objective(trial):
        params = {
            'C': trial.suggest_float('C', 1e-4, 1e2, log=True),
            'penalty': trial.suggest_categorical('penalty', ['l1', 'l2']),
            'solver': trial.suggest_categorical('solver', ['liblinear', 'saga']),
            'max_iter': trial.suggest_int('max_iter', 100, 500)
        }
        clf = LogisticRegression(**params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=-1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()


    # KNN
    def knn_objective(trial):
        params = {
            'n_neighbors': trial.suggest_int('n_neighbors', 1, 50),
            'leaf_size': trial.suggest_int('leaf_size', 10, 50),
            'p': trial.suggest_categorical('p', [1, 2]),
            'algorithm': trial.suggest_categorical('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute'])
        }
        clf = KNeighborsClassifier(n_jobs=N_JOBS, **params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=-1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # SVC
    def svc_objective(trial):
        params = {
            'C': trial.suggest_float('C', 1e-2, 1e2, log=True),
            'kernel': trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']),
            'gamma': trial.suggest_categorical('gamma', ['scale', 'auto'])
        }
        clf = SVC(**params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=-1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # Random Forest
    def random_forest_objective(trial):
        params = {
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 400, 500, 800, 1400, 2000]),
            'max_depth': trial.suggest_int('max_depth', 2, 40),
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
            'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10)
        }
        clf = RandomForestClassifier(random_state=RANDOM_SEED, n_jobs=N_JOBS, **params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # XGBoost
    def xgb_objective(trial):
        params = {
            'n_estimators': trial.suggest_categorical('n_estimators', [50, 100, 200, 400, 800, 1000, 2000, 5000]),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1.0, log=True),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0)
        }
        clf = xgb.XGBClassifier(random_state=RANDOM_SEED, n_jobs=N_JOBS, verbosity=0, **params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # CatBoost
    def catboost_objective(trial):
        params = {
            'iterations': trial.suggest_categorical('n_estimators', [50, 100, 200, 400, 800, 1000, 2000, 5000]),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1.0, log=True),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-2, 10.0, log=True),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),            
            'depth': trial.suggest_int('depth', 3, 10)
        }
        clf = cb.CatBoostClassifier(random_seed=RANDOM_SEED, thread_count=N_JOBS, verbose=False, **params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # LightGBM
    def lgbm_objective(trial):
        params = {
            'n_estimators': trial.suggest_categorical('n_estimators', [50, 100, 200, 400, 800, 1000, 2000, 5000]),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1.0, log=True),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'num_leaves': trial.suggest_int('num_leaves', 20, 150)
        }
        clf = lgb.LGBMClassifier(random_state=RANDOM_SEED, n_jobs=N_JOBS, verbose=0, **params)
        kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
        score = cross_val_score(clf, X, y, n_jobs=1, cv=kfold, scoring='roc_auc')
        return score.mean() - score.std()

    # Adding each objective to the dict
    objectives['LR'] = logistic_regression_objective
    objectives['KNN'] = knn_objective
    objectives['SVC'] = svc_objective
    objectives['RF'] = random_forest_objective
    objectives['XGB'] = xgb_objective
    objectives['CB'] = catboost_objective
    objectives['LGB'] = lgbm_objective

    return objectives

# %%
ds = [
    {
        'X': pd.read_pickle('../data/processed/X_train_1.pkl'),
        'y': pd.read_pickle('../data/processed/y_train_1.pkl'),        
    },
    {
        'X': pd.read_pickle('../data/processed/X_train_2.pkl'),
        'y': pd.read_pickle('../data/processed/y_train_2.pkl'),         
    },
    {
        'X': pd.read_pickle('../data/processed/X_train_3.pkl'),
        'y': pd.read_pickle('../data/processed/y_train_3.pkl'), 
    }
]

# %%
pd.read_pickle('../data/processed/X_train_1.pkl').shape
# Out:
# (5094, 2880)

# %%
import optuna
import pickle

X = pd.read_pickle('../data/processed/X_train_1.pkl')
y = pd.read_pickle('../data/processed/y_train_1.pkl')       

FPS_OFFSET = get_fps_offset(X.columns)
scaler = OffsetScaler(FPS_OFFSET)
X_scaled = scaler.fit_transform(X.values)


objectives = get_objectives(X_scaled, y)
for name in ['SVC', 'RF', 'XGB', 'CB','LGB']:
    obj = objectives[name]        
    study = optuna.create_study(direction='maximize')
    study.optimize(obj, n_trials=200)
    with open('../data/tuning/' + name + '_dataset_1.pkl', 'wb') as f:
        pickle.dump(study, f)
# Out:
# [I 2024-09-05 21:37:45,369] A new study created in memory with name: no-name-d800db51-d355-415c-9388-966163563ed1
# /tmp/ipykernel_153493/2027625652.py:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'C': trial.suggest_loguniform('C', 1e-2, 1e2),
# [I 2024-09-05 21:38:14,061] Trial 0 finished with value: 0.6727358355657935 and parameters: {'C': 25.518919157916944, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 0 with value: 0.6727358355657935.
# [I 2024-09-05 21:38:58,716] Trial 1 finished with value: 0.8068849433058622 and parameters: {'C': 65.9437817772043, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 1 with value: 0.8068849433058622.
# [I 2024-09-05 21:39:55,746] Trial 2 finished with value: 0.826238743668484 and parameters: {'C': 0.5452636957750135, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 2 with value: 0.826238743668484.
# [I 2024-09-05 21:40:38,538] Trial 3 finished with value: 0.8359598519655799 and parameters: {'C': 0.24009272011305574, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 3 with value: 0.8359598519655799.
# [I 2024-09-05 21:41:28,637] Trial 4 finished with value: 0.8742125094239942 and parameters: {'C': 6.248739612722452, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 4 with value: 0.8742125094239942.
# [I 2024-09-05 21:42:10,208] Trial 5 finished with value: 0.8675058674792452 and parameters: {'C': 0.024523199452274234, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial
 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:17:00,128] Trial 13 finished with value: 0.8857956991518453 and parameters: {'n_estimators': 800, 'max_depth': 16, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:17:08,311] Trial 14 finished with value: 0.8858356422504073 and parameters: {'n_estimators': 400, 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:17:16,360] Trial 15 finished with value: 0.8846042334042022 and parameters: {'n_estimators': 400, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:17:31,537] Trial 16 finished with value: 0.878882599352779 and parameters: {'n_estimators': 800, 'max_depth': 40, 'min_samples_split': 20, 'min_samples_leaf': 5}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:17:57,245] Trial 17 finished with value: 0.8740565891190903 and parameters: {'n_estimators': 1400, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:18:07,374] Trial 18 finished with value: 0.8870961514384768 and parameters: {'n_estimators': 500, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:18:13,495] Trial 19 finished with value: 0.880112611416708 and parameters: {'n_estimators': 300, 'max_depth': 19, 'min_samples_split': 17, 'min_samples_leaf': 5}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:18:21,535] Trial 20 finished with value: 0.8806169326261826 and parameters: {'n_estimators': 400, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:18:37,653] Trial 21 finished with value: 0.8887421762442074 and parameters: {'n_estimators': 800, 'max_depth': 40, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:18:53,615] Trial 22 finished with value: 0.887709938524545 and parameters: {'n_estimators': 800, 'max_depth': 35, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:19:09,164] Trial 23 finished with value: 0.8863241858202855 and parameters: {'n_estimators': 800, 'max_depth': 38, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:19:24,597] Trial 24 finished with value: 0.8870797147662303 and parameters: {'n_estimators': 800, 'max_depth': 30, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 11 with value: 0.8904076429935124.
# [I 2024-09-06 00:19:40,902] Trial 25 finished with value: 0.8905104605235168 and parameters: {'n_estimators': 800, 'max_depth': 37, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 25 with value: 0.8905104605235168.
# [I 2024-09-06 00:19:49,048] Trial 26 finished with value: 0.8866528073562436 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 25 with value: 0.8905104605235168.
# [I 2024-09-06 00:20:05,111] Trial 27 finished with value: 0.8896454171287711 and parameters: {'n_estimators': 800, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 25 with value: 0.8905104605235168.
# [I 2024-09-06 00:20:09,504] Trial 28 finished with value: 0.8817025873246579 and parameters: {'n_estimators': 200, 'max_depth': 37, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 25 with value: 0.8905104605235168.
# ...
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:17:26,898] Trial 41 finished with value: 0.8988977324847147 and parameters: {'n_estimators': 1000, 'learning_rate': 0.016793203462636828, 'max_depth': 6, 'subsample': 0.9678503184453857, 'colsample_bytree': 0.6568309542345919}. Best is trial 10 with value: 0.9002826127638085.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:19:07,631] Trial 42 finished with value: 0.9006389486527007 and parameters: {'n_estimators': 1000, 'learning_rate': 0.024079545418467577, 'max_depth': 7, 'subsample': 0.9599203343590555, 'colsample_bytree': 0.5973057500158327}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:20:36,101] Trial 43 finished with value: 0.8966823891897056 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08101762620448183, 'max_depth': 7, 'subsample': 0.9516481346343995, 'colsample_bytree': 0.595280542260701}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:30:09,012] Trial 44 finished with value: 0.9004687788343557 and parameters: {'n_estimators': 5000, 'learning_rate': 0.0060554774551807265, 'max_depth': 8, 'subsample': 0.924370666688333, 'colsample_bytree': 0.5399532156896136}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:40:53,421] Trial 45 finished with value: 0.9001413319432663 and parameters: {'n_estimators': 5000, 'learning_rate': 0.005874001899392834, 'max_depth': 9, 'subsample': 0.9257619783142469, 'colsample_bytree': 0.5248058002395402}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 03:55:43,544] Trial 46 finished with value: 0.8907678513354222 and parameters: {'n_estimators': 5000, 'learning_rate': 0.0006341965490660505, 'max_depth': 9, 'subsample': 0.6026790233218817, 'colsample_bytree': 0.5345103325245429}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 04:06:47,484] Trial 47 finished with value: 0.899608360478851 and parameters: {'n_estimators': 5000, 'learning_rate': 0.006967803053531146, 'max_depth': 10, 'subsample': 0.8812447652991574, 'colsample_bytree': 0.5008719436824803}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 04:19:23,564] Trial 48 finished with value: 0.9001511710218876 and parameters: {'n_estimators': 5000, 'learning_rate': 0.002911608505756316, 'max_depth': 9, 'subsample': 0.9277732593534201, 'colsample_bytree': 0.5547949419950823}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 04:30:28,354] Trial 49 finished with value: 0.8995843381162824 and parameters: {'n_estimators': 5000, 'learning_rate': 0.002256620977144771, 'max_depth': 8, 'subsample': 0.8160043679505261, 'colsample_bytree': 0.5494593987883585}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 04:42:42,417] Trial 50 finished with value: 0.9006076999592534 and parameters: {'n_estimators': 5000, 'learning_rate': 0.003124884868259986, 'max_depth': 9, 'subsample': 0.929350265759018, 'colsample_bytree': 0.5198991887615705}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 04:54:50,046] Trial 51 finished with value: 0.9002337249162948 and parameters: {'n_estimators': 5000, 'learning_rate': 0.0032565681253365598, 'max_depth': 9, 'subsample': 0.9260759066404494, 'colsample_bytree': 0.5203499008946568}. Best is trial 42 with value: 0.9006389486527007.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 05:07:06,547] Trial 52 finished with value: 0.9007524956102174 and parameters: {'n_estimators': 5000, 'learning_rate': 0.003181225469259462, 'max_depth': 9, 'subsample': 0.8577483248401714, 'colsample_bytree': 0.5164153463247417}. Best is trial 52 with value: 0.9007524956102174.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-09-06 05:19:00,153] Trial 53 finished with value: 0.897575181599598 and parameters: {'n_estimators': 5000, 'learning_rate': 0.0013978000261489145, 'max_depth': 8, 'subsample': 0.8556368292093254, 'colsample_bytree': 0.5195097100450408}. Best is trial 52 with value: 0.9007524956102174.
# /tmp/ipykernel_153493/2027625652.py:60: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
# /tmp/ipykernel_153493/2027625652.py:62: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# /tmp/ipykernel_153493/2027625652.py:63: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0)

# %%
import pickle

with open('../data/tuning/LGB.pkl', 'rb') as f:
    study = pickle.load(f)
    
study.best_params
